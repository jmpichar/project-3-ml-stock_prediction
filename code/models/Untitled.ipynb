# %%
from stock_prediction import *
# Out:
# Using TensorFlow backend.

# %%
df = get_stock_data('intc')
# Out:
# Checking for null values

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///data_tst.db', echo=False)

# %%
#config['SQLALCHEMY_DATABASE_URI'] = 'sqlite:///data.db'

# %%
df.to_sql('test', con=engine)

# %%
engine.execute('SELECT * FROM test').fetchall()
# Out:
# [('1999-08-10', 36.4688, 37.2188, 35.7813, 35.875, 67205200.0),
#  ('1999-08-11', 36.9688, 38.125, 36.7813, 38.0, 80989400.0),
#  ('1999-08-12', 37.7188, 38.375, 37.5313, 37.9688, 48030000.0),
#  ('1999-08-13', 38.4688, 39.9063, 38.4688, 39.875, 46873400.0),
#  ('1999-08-16', 39.625, 39.7188, 38.8125, 39.2813, 35343600.0),
#  ('1999-08-17', 39.6563, 39.75, 38.75, 39.5, 32726200.0),
#  ('1999-08-18', 39.2188, 39.9063, 39.0313, 39.25, 32524600.0),
#  ('1999-08-19', 38.75, 39.1563, 38.4063, 38.6563, 32120600.0),
#  ('1999-08-20', 38.9688, 40.0313, 38.5, 39.9688, 35718000.0),
#  ('1999-08-23', 40.25, 41.5, 39.9688, 41.4688, 49839000.0),
#  ('1999-08-24', 41.1563, 42.25, 41.125, 41.5625, 61735000.0),
#  ('1999-08-25', 41.375, 42.1875, 40.6875, 41.8438, 48070800.0),
#  ('1999-08-26', 41.7188, 41.9375, 40.4375, 40.5313, 43461800.0),
#  ('1999-08-27', 41.1875, 41.75, 40.9063, 41.5, 40881200.0),
#  ('1999-08-30', 41.5313, 42.0625, 40.5625, 41.125, 34043600.0),
# ...

# %%
# !pwd
# Out:
# /home/jmpichar/edu/bcs/homework/project-3-ml/v1/code/models
